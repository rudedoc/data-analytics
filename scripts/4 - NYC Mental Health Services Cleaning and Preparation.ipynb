# %%
# check for required file

import os
from pathlib import Path

FILE_PATH = '../data/NYC_Local_Mental_Health_Programs.csv'

file_path = Path(FILE_PATH)

# Check if the file exists
if file_path.exists():
    print(f"File found: {file_path}")
else:
    print(f"File not found: {file_path}. Please ensure the file is downloaded correctly.")
# Out:
# File found: ../data/NYC_Local_Mental_Health_Programs.csv

# %%
# Load the dataset
import pandas as pd
import numpy as np

initial_df = pd.read_csv(FILE_PATH)

initial_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4952 entries, 0 to 4951
# Data columns (total 28 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Row Created Date Time             4952 non-null   object
#  1    Sponsor Name                     4952 non-null   object
#  2    Sponsor Code                     4952 non-null   int64
#  3    Agency Name                      4952 non-null   object
#  4    Agency Code                      4952 non-null   int64
#  5   Facility Name                     4952 non-null   object
#  6    Facility Code                    4952 non-null   int64
#  7    Program Name                     4952 non-null   object
#  8    Program Code                     4952 non-null   int64
#  9    Populations Served               4728 non-null   object
#  10   Agency Phone                     4948 non-null   object
#  11   Program Phone                    4919 non-null   object
#  12    Program Address 1               3380 non-null   object
#  13   Program Address 2                836 non-null    object
#  14   Program City                     3380 non-null   object
#  15   Program State                    4952 non-null   object
#  16   Program Zip                      3380 non-null   object
#  17   Operating Certificate Required?  4952 non-null   object
#  18   Program Tier                     427 non-null    float64
#  19   Operating Certificate Duration   1537 non-null   float64
#  20   Program County                   4952 non-null   object
#  21   Program Region                   4952 non-null   object
#  22   Program Type Description         4952 non-null   object
#  23   Program Category Description     4952 non-null   object
#  24   Program Subcategory Description  4952 non-null   object
#  25  Location                          3315 non-null   object
#  26  Counties                          2933 non-null   float64
#  27  New York Zip Codes                2945 non-null   float64
# dtypes: float64(4), int64(4), object(20)
# memory usage: 1.1+ MB

# %%
initial_df.head()
# Out:
#      Row Created Date Time                               Sponsor Name  \
# 0  2018-04-27T09:52:56.000  Albany County Department of Mental Health
# 1  2018-04-27T09:52:56.000  Albany County Department of Mental Health
# 2  2018-04-27T09:52:56.000  Albany County Department of Mental Health
# 3  2018-04-27T09:52:56.000  Albany County Department of Mental Health
# 4  2018-04-27T09:52:56.000  Albany County Department of Mental Health
#
#     Sponsor Code                                Agency Name   Agency Code  \
# 0           8099  Albany County Department of Mental Health         70520
# 1           8099  Albany County Department of Mental Health         70520
# 2           8099  Albany County Department of Mental Health         70520
# 3           8099  Albany County Department of Mental Health         70520
# 4           8099  Albany County Department of Mental Health         70520
#
#                                Facility Name   Facility Code  \
# 0  Albany County Department of Mental Health            6901
# 1  Albany County Department of Mental Health            6901
# 2  Albany County Department of Mental Health            6901
# 3  Albany County Department of Mental Health            6901
# 4  Albany County Department of Mental Health            6901
#
#                          Program Name   Program Code  \
# 0           Albany County ACT Program            471
# 1            Albany County DMH - HHCM             18
# 2    Albany County DMH - HH NonMed CM             17
# 3  Albany County Mental Health Clinic            100
# 4                  Mobile Crisis Team             19
#
#             Populations Served  ...  Program Tier  \
# 0                       Adults  ...           NaN
# 1                       Adults  ...           NaN
# 2                       Adults  ...           NaN
# 3  Children Adolescents Adults  ...           NaN
# 4                       Adults  ...           NaN
#
#    Operating Certificate Duration  Program County  Program Region  \
# 0                            36.0          Albany    Hudson River
# 1                             NaN          Albany    Hudson River
# 2                             NaN          Albany    Hudson River
# 3                            36.0          Albany    Hudson River
# 4                             NaN          Albany    Hudson River
#
#                    Program Type Description  Program Category Description  \
# 0       Assertive Community Treatment (ACT)                    Outpatient
# 1               Health Home Care Management                       Support
# 2  Health Home Non-Medicaid Care Management                       Support
# 3                          Clinic Treatment                    Outpatient
# 4                      Crisis  Intervention                     Emergency
#
#    Program Subcategory Description  \
# 0    Assertive Community Treatment
# 1                Care Coordination
# 2                Care Coordination
# 3                 Clinic Treatment
# 4                           Crisis
#
#                                             Location  Counties  \
# 0  {'human_address': '{"address": "175 Green Stre...    2030.0
# 1  {'human_address': '{"address": "175 Green Stre...    2030.0
# 2  {'human_address': '{"address": "175 Green Stre...    2030.0
# 3  {'human_address': '{"address": "260 South Pear...    2030.0
# 4  {'human_address': '{"address": "75 New Scotlan...    2030.0
#
#    New York Zip Codes
# 0                39.0
# 1                39.0
# 2                39.0
# 3                39.0
# 4                45.0
#
# [5 rows x 28 columns]

# %%
# Columns to drop
columns_to_keep = [' Program Subcategory Description', ' Program Category Description', ' Program Type Description',
                   ' Populations Served', ' Program Name', ' Program County', 'New York Zip Codes']

# Drop the columns
initial_df = initial_df[columns_to_keep]
initial_df.head()
# Out:
#    Program Subcategory Description  Program Category Description  \
# 0    Assertive Community Treatment                    Outpatient
# 1                Care Coordination                       Support
# 2                Care Coordination                       Support
# 3                 Clinic Treatment                    Outpatient
# 4                           Crisis                     Emergency
#
#                    Program Type Description           Populations Served  \
# 0       Assertive Community Treatment (ACT)                       Adults
# 1               Health Home Care Management                       Adults
# 2  Health Home Non-Medicaid Care Management                       Adults
# 3                          Clinic Treatment  Children Adolescents Adults
# 4                      Crisis  Intervention                       Adults
#
#                          Program Name  Program County  New York Zip Codes
# 0           Albany County ACT Program          Albany                39.0
# 1            Albany County DMH - HHCM          Albany                39.0
# 2    Albany County DMH - HH NonMed CM          Albany                39.0
# 3  Albany County Mental Health Clinic          Albany                39.0
# 4                  Mobile Crisis Team          Albany                45.0

# %%
# Count the number of NaN values per column
nan_counts = initial_df.isna().sum()


# Print the NaN counts
print(nan_counts)
# Out:
#  Program Subcategory Description       0
#  Program Category Description          0
#  Program Type Description              0
#  Populations Served                  224
#  Program Name                          0
#  Program County                        0
# New York Zip Codes                  2007
# dtype: int64

# %%
initial_df[' Populations Served'] = initial_df[' Populations Served'].fillna('Adults')

# %%
# Count the number of NaN values per column
nan_counts = initial_df.isna().sum()


# Print the NaN counts
print(nan_counts)
# Out:
#  Program Subcategory Description       0
#  Program Category Description          0
#  Program Type Description              0
#  Populations Served                    0
#  Program Name                          0
#  Program County                        0
# New York Zip Codes                  2007
# dtype: int64

# %%
initial_df[' Program County'].unique()
# Out:
# array(['Albany', 'Allegany', 'Bronx', 'Broome', 'Cattaraugus', 'Cayuga',
#        'Chautauqua', 'Chemung', 'Chenango', 'Clinton', 'Columbia',
#        'Cortland', 'Delaware', 'Dutchess', 'Erie', 'Essex', 'Franklin',
#        'Fulton', 'Genesee', 'Greene', 'Hamilton', 'Herkimer', 'Jefferson',
#        'Kings', 'Lewis', 'Livingston', 'Madison', 'Monroe', 'Montgomery',
#        'Nassau', 'New York', 'Niagara', 'Oneida', 'Onondaga', 'Ontario',
#        'Orange', 'Orleans', 'Oswego', 'Otsego', 'Putnam', 'Queens',
#        'Rensselaer', 'Richmond', 'Rockland', 'Saratoga', 'Schenectady',
#        'Schoharie', 'Schuyler', 'Seneca', 'Steuben', 'St. Lawrence',
#        'Suffolk', 'Sullivan', 'Tioga', 'Tompkins', 'Ulster',
#        'USA Not NYS', 'Warren', 'Washington', 'Wayne', 'Westchester',
#        'Wyoming', 'Yates'], dtype=object)

# %%
count = (initial_df[' Program County'] == "New York").sum()
print(f"Number of rows where Program County is 'New York': {count}")
# Out:
# Number of rows where Program County is 'New York': 471
